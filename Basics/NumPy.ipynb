# %%
import numpy as np
import pandas

# %%
b = np.empty(2, dtype="int")
print("b: ", b)

a = np.empty([2, 2], dtype="int")
print("a: ", a)

c = np.empty([3, 3], dtype="int")
print("c: ", c)
# Out:
# b:  [416611827831 472446402674]
# a:  [[0 0]
#  [0 0]]
# c:  [[ 4154869048758490228 -5063999388468915077  4150365449131119754]
#  [-5063999388468915079  4164493454808879278 -5066291870852750681]
#  [ 4150365449131119750 -5066291870852750683  4153281945569680965]]

# %%
a = np.array([5, 6, 7, 8])
b = np.array([2, 5, 10, 10])

print(a+b)
print(np.add(a, b))
# Out:
# [ 7 11 17 18]
# [ 7 11 17 18]

# %%
import pandas as pd

# %%
# Read CSV file and stores in df
df = pd.read_csv("test.csv")

#Displays top 5 entries of (header)
df.head()
# Out:
#                                                 text  label
# 0  im feeling rather rotten so im not very ambiti...      0
# 1          im updating my blog because i feel shitty      0
# 2  i never make her separate from me because i do...      0
# 3  i left with my bouquet of red and yellow tulip...      1
# 4    i was feeling a little vain when i did this one      0

# %%
df.info()
# 0 null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2000 non-null   object
#  1   label   2000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#             label
# count  2000.00000
# mean      1.53200
# std       1.47447
# min       0.00000
# 25%       0.00000
# 50%       1.00000
# 75%       3.00000
# max       5.00000

# %%
df.label.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) # x and y co-ordinates
plt.axis([0, 6, 0, 20]) # x-axis from 0 to 6 and y-axis from 0 to 20
plt.show()

# %%
import pandas as pd
df2 = pd.read_excel("CocaCola_Sales_Rawdata.xlsx")
df2.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
df2.Sales.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import seaborn as sns
from pandas.plotting import lag_plot
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings("ignore")

# %%
v = pd.read_excel('CocaCola_Sales_Rawdata.xlsx', header=0, index_col=0, parse_dates=True)

# %%
lag_plot(v)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>
